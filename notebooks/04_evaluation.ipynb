# %% [markdown]
# # Spotify Recommender System – Part 4: Evaluation
# **Author:** Miguel Vásquez
# **Date:** 22 September 2025
#
# ---
#
# ## 1. Introduction
#
# This notebook consolidates and compares the performance of all implemented models:
# - Popularity baseline
# - ALS (Matrix Factorization)
# - LightFM (Hybrid Collaborative Filtering)
#
# We evaluate them using ranking-aware metrics that reflect real-world recommendation quality.
#
# ---
#
# ## 2. Objectives of this notebook
#
# - Implement evaluation metrics: Precision@K, Recall@K, NDCG@K, and Hit Rate.
# - Compare results across models.
# - Discuss trade-offs between accuracy, coverage, and scalability.
# - Summarize findings and outline next steps for improvement.
